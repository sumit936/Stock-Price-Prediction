# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import KMeans
import warnings
warnings.filterwarnings('ignore')
sns.set(style='darkgrid')

# %% [markdown]
# ## Problem [6.1]

# %%
# Dataframe Created to store Close Price of 30 Stocks
data=pd.DataFrame()

# %%
# stocks of 10 Large Cap Companies

data['infy']=pd.read_csv(r"C:\Users\HP\Desktop\Machine learning\Projects\Stock Price prediction\Dataset\Large_Cap\INFY.csv")['Close Price']
data['ioc']=pd.read_csv(r"C:\Users\HP\Desktop\Machine learning\Projects\Stock Price prediction\Dataset\Large_Cap\IOC.csv")['Close Price']
data['itc']=pd.read_csv(r"C:\Users\HP\Desktop\Machine learning\Projects\Stock Price prediction\Dataset\Large_Cap\ITC.csv")['Close Price']
data['lt']=pd.read_csv(r"C:\Users\HP\Desktop\Machine learning\Projects\Stock Price prediction\Dataset\Large_Cap\LT.csv")['Close Price']
data['mm']=pd.read_csv(r"C:\Users\HP\Desktop\Machine learning\Projects\Stock Price prediction\Dataset\Large_Cap\M&M.csv")['Close Price']
data['maruti']=pd.read_csv(r"C:\Users\HP\Desktop\Machine learning\Projects\Stock Price prediction\Dataset\Large_Cap\MARUTI.csv")['Close Price']
data['reliance']=pd.read_csv(r"C:\Users\HP\Desktop\Machine learning\Projects\Stock Price prediction\Dataset\Large_Cap\RELIANCE.csv")['Close Price']
data['sunpharma']=pd.read_csv(r"C:\Users\HP\Desktop\Machine learning\Projects\Stock Price prediction\Dataset\Large_Cap\SUNPHARMA.csv")['Close Price']
data['tcs']=pd.read_csv(r"C:\Users\HP\Desktop\Machine learning\Projects\Stock Price prediction\Dataset\Large_Cap\TCS.csv")['Close Price']
data['titan']=pd.read_csv(r"C:\Users\HP\Desktop\Machine learning\Projects\Stock Price prediction\Dataset\Large_Cap\TITAN.csv")['Close Price']

# %%
# stocks of 10 Mid Cap Companies

data['idbi']=pd.read_csv(r"C:\Users\HP\Desktop\Machine learning\Projects\Stock Price prediction\Dataset\Mid_Cap\IDBI.csv")['Close Price']
data['igl']=pd.read_csv(r"C:\Users\HP\Desktop\Machine learning\Projects\Stock Price prediction\Dataset\Mid_Cap\IGL.csv")['Close Price']
data['jindals']=pd.read_csv(r"C:\Users\HP\Desktop\Machine learning\Projects\Stock Price prediction\Dataset\Mid_Cap\JINDALSTEL.csv")['Close Price']
data['jublfood']=pd.read_csv(r"C:\Users\HP\Desktop\Machine learning\Projects\Stock Price prediction\Dataset\Mid_Cap\JUBLFOOD.csv")['Close Price']
data['mindtree']=pd.read_csv(r"C:\Users\HP\Desktop\Machine learning\Projects\Stock Price prediction\Dataset\Mid_Cap\MINDTREE.csv")['Close Price']
data['mrpl']=pd.read_csv(r"C:\Users\HP\Desktop\Machine learning\Projects\Stock Price prediction\Dataset\Mid_Cap\MRPL.csv")['Close Price']
data['muthootfin']=pd.read_csv(r"C:\Users\HP\Desktop\Machine learning\Projects\Stock Price prediction\Dataset\Mid_Cap\MUTHOOTFIN.csv")['Close Price']
data['nbcc']=pd.read_csv(r"C:\Users\HP\Desktop\Machine learning\Projects\Stock Price prediction\Dataset\Mid_Cap\NBCC.csv")['Close Price']
data['pnb']=pd.read_csv(r"C:\Users\HP\Desktop\Machine learning\Projects\Stock Price prediction\Dataset\Mid_Cap\PNB.csv")['Close Price']
data['rblbank']=pd.read_csv(r"C:\Users\HP\Desktop\Machine learning\Projects\Stock Price prediction\Dataset\Mid_Cap\RBLBANK.csv")['Close Price']

# %%
# stocks of 10 Small Cap Companies

data['luxind']=pd.read_csv(r"C:\Users\HP\Desktop\Machine learning\Projects\Stock Price prediction\Dataset\Small_Cap\LUXIND.csv")['Close Price']
data['mindaind']=pd.read_csv(r"C:\Users\HP\Desktop\Machine learning\Projects\Stock Price prediction\Dataset\Small_Cap\MINDAIND.csv")['Close Price']
data['ncc']=pd.read_csv(r"C:\Users\HP\Desktop\Machine learning\Projects\Stock Price prediction\Dataset\Small_Cap\NCC.csv")['Close Price']
data['pvr']=pd.read_csv(r"C:\Users\HP\Desktop\Machine learning\Projects\Stock Price prediction\Dataset\Small_Cap\PVR.csv")['Close Price']
data['raymond']=pd.read_csv(r"C:\Users\HP\Desktop\Machine learning\Projects\Stock Price prediction\Dataset\Small_Cap\RAYMOND.csv")['Close Price']
data['rcom']=pd.read_csv(r"C:\Users\HP\Desktop\Machine learning\Projects\Stock Price prediction\Dataset\Small_Cap\RCOM.csv")['Close Price']
data['sonatsoftw']=pd.read_csv(r"C:\Users\HP\Desktop\Machine learning\Projects\Stock Price prediction\Dataset\Small_Cap\SONATSOFTW.csv")['Close Price']
data['suzlon']=pd.read_csv(r"C:\Users\HP\Desktop\Machine learning\Projects\Stock Price prediction\Dataset\Small_Cap\SUZLON.csv")['Close Price']
data['venkeys']=pd.read_csv(r"C:\Users\HP\Desktop\Machine learning\Projects\Stock Price prediction\Dataset\Small_Cap\VENKEYS.csv")['Close Price']
data['vipind']=pd.read_csv(r"C:\Users\HP\Desktop\Machine learning\Projects\Stock Price prediction\Dataset\Small_Cap\VIPIND.csv")['Close Price']

# %%
# As the data contains missing values 
# So We Shall Remove the missing values by dropna function
print('### Before Null Removal ###\n')
print(data.isnull().sum())

data.dropna(inplace=True)


print('\n### After Null Removal ###')
data.isnull().sum()
# Out:
# ### Before Null Removal ###
#
# infy          0
# ioc           1
# itc           0
# lt            2
# mm            0
# maruti        0
# reliance      1
# sunpharma     1
# tcs           0
# titan         0
# idbi          2
# igl           0
# jindals       2
# jublfood      1
# mindtree      2
# mrpl          2
# muthootfin    0
# nbcc          2
# pnb           2
# rblbank       2
# luxind        2
# mindaind      1
# ncc           0
# pvr           1
# raymond       2
# rcom          2
# sonatsoftw    2
# suzlon        2
# venkeys       2
# vipind        2
# dtype: int64
#
# ### After Null Removal ###
# infy          0
# ioc           0
# itc           0
# lt            0
# mm            0
# maruti        0
# reliance      0
# sunpharma     0
# tcs           0
# titan         0
# idbi          0
# igl           0
# jindals       0
# jublfood      0
# mindtree      0
# mrpl          0
# muthootfin    0
# nbcc          0
# pnb           0
# rblbank       0
# luxind        0
# ...

# %%
data
# Out:
#        infy     ioc     itc       lt       mm   maruti  reliance  sunpharma  \
# 0    951.55  442.10  277.95  1742.40  1375.65  6823.90   1344.10     654.45
# 1    955.00  446.60  283.45  1740.70  1366.35  6953.95   1356.30     652.35
# 2    952.80  444.25  281.65  1755.45  1378.80  6958.20   1353.10     650.90
# 3    961.75  439.90  277.90  1722.60  1352.85  6831.05   1327.35     653.95
# 4    957.95  435.40  286.20  1724.55  1333.40  6790.55   1318.85     653.15
# ..      ...     ...     ...      ...      ...      ...       ...        ...
# 489  723.60  156.70  304.25  1366.60   645.90  6710.00   1384.90     453.15
# 490  718.40  153.45  307.00  1360.35   645.80  6709.65   1343.50     448.20
# 491  724.55  152.20  301.90  1356.45   638.50  6702.00   1299.45     439.15
# 492  719.35  150.60  300.65  1355.50   636.00  6650.15   1256.45     439.35
# 493  721.05  147.60  299.85  1317.65   621.65  6624.95   1251.15     437.75
#
# ...

# %%
# list of Stocks
stock_list=list(data.columns)

# %% [markdown]
# ## Problem [6.2]

# %%
# Dataframe Containing the Daily Return of 30 stocks
daily_ret=pd.DataFrame()
for i in stock_list:
    daily_ret[i]=data[i].pct_change()
    daily_ret[i][0]=0

# %%
daily_ret
# Out:
#          infy       ioc       itc        lt        mm    maruti  reliance  \
# 0    0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 1    0.003626  0.010179  0.019788 -0.000976 -0.006760  0.019058  0.009077
# 2   -0.002304 -0.005262 -0.006350  0.008474  0.009112  0.000611 -0.002359
# 3    0.009393 -0.009792 -0.013314 -0.018713 -0.018821 -0.018273 -0.019030
# 4   -0.003951 -0.010230  0.029867  0.001132 -0.014377 -0.005929 -0.006404
# ..        ...       ...       ...       ...       ...       ...       ...
# 489 -0.009852  0.003522 -0.002459  0.010276  0.000930  0.004003 -0.017000
# 490 -0.007186 -0.020740  0.009039 -0.004573 -0.000155 -0.000052 -0.029894
# 491  0.008561 -0.008146 -0.016612 -0.002867 -0.011304 -0.001140 -0.032787
# 492 -0.007177 -0.010512 -0.004140 -0.000700 -0.003915 -0.007736 -0.033091
# 493  0.002363 -0.019920 -0.002661 -0.027923 -0.022563 -0.003789 -0.004218
#
#      sunpharma       tcs     titan  ...    luxind  mindaind       ncc  \
# ...

# %%
print('### Annual Return ###')
round(daily_ret.mean()*252,2)
# Out:
# ### Annual Return ###
# infy           -0.02
# ioc            -0.40
# itc             0.06
# lt             -0.09
# mm             -0.27
# maruti          0.01
# reliance        0.09
# sunpharma      -0.15
# tcs             0.08
# titan           0.47
# idbi           -0.30
# igl            -0.13
# jindals         0.27
# jublfood        0.27
# mindtree        0.39
# mrpl           -0.32
# muthootfin    104.39
# nbcc           -0.51
# pnb            -0.24
# rblbank         0.11
# luxind          0.25
# mindaind        0.08
# ncc             0.08
# pvr             0.11
# raymond         0.07
# rcom           -0.88
# sonatsoftw      0.46
# suzlon         -0.47
# venkeys         0.38
# vipind          0.48
# dtype: float64

# %%
print('### Volatility ###')
round(((daily_ret.std())*(252**0.5)),2)
# Out:
# ### Volatility ###
# infy           0.42
# ioc            0.50
# itc            0.22
# lt             0.31
# mm             0.44
# maruti         0.23
# reliance       0.44
# sunpharma      0.34
# tcs            0.43
# titan          0.32
# idbi           0.45
# igl            0.65
# jindals        0.49
# jublfood       0.50
# mindtree       0.34
# mrpl           0.37
# muthootfin    18.28
# nbcc           0.51
# pnb            0.54
# rblbank        0.26
# luxind         0.34
# mindaind       0.61
# ncc            0.44
# pvr            0.31
# raymond        0.36
# rcom           0.98
# sonatsoftw     0.40
# suzlon         0.59
# venkeys        0.63
# vipind         0.43
# dtype: float64

# %% [markdown]
# ## Problem [6.3]

# %%
returns = daily_ret.mean() * 252
volatility = data.pct_change().std() * (252**0.5)
returns.columns = ["Returns"]
volatility.columns = ["Volatility"]
#Concatenating the returns and variances into a single data-frame
ret_var = pd.concat([returns, volatility], axis = 1).dropna()
ret_var.columns = ["Annual Returns","Volatility"]

# %%
ret_var
# Out:
#             Annual Returns  Volatility
# infy             -0.022626    0.418963
# ioc              -0.395583    0.499514
# itc               0.063885    0.223863
# lt               -0.085730    0.314323
# mm               -0.268613    0.440357
# maruti            0.010174    0.225258
# reliance          0.094928    0.439091
# sunpharma        -0.146316    0.342426
# tcs               0.080307    0.431387
# titan             0.472152    0.324361
# idbi             -0.295409    0.453787
# igl              -0.131495    0.651128
# jindals           0.274814    0.492980
# jublfood          0.266973    0.501004
# mindtree          0.391775    0.341485
# mrpl             -0.322303    0.365898
# muthootfin      104.385879   18.299167
# nbcc             -0.514133    0.508672
# pnb              -0.238955    0.545390
# rblbank           0.113267    0.258732
# luxind            0.254644    0.335409
# mindaind          0.081559    0.607996
# ncc               0.076986    0.441393
# ...

# %%
X = ret_var.values
distorsions = []
for k in range(2, 20):
    k_means = KMeans(n_clusters=k)
    k_means.fit(X)
    distorsions.append(k_means.inertia_)
fig = plt.figure(figsize=(15, 5))
plt.plot(range(2, 20), distorsions)
plt.grid(True)
plt.title('Elbow curve')
# Out:
# Text(0.5, 1.0, 'Elbow curve')

# %% [markdown]
# ## Problem [6.4]

# %%
# The Outlier Need to be removed
print(returns.idxmax())
# Out:
# muthootfin

# %%
ret_var.drop(ret_var.idxmax(), inplace =True)

# %%
X=ret_var.values
km=KMeans(n_clusters=5)
kmeans=km.fit_predict(X)
n=list(ret_var.index)
z=list(ret_var['Annual Returns'])
y=list(ret_var['Volatility'])
plt.figure(figsize=(20,8))
plt.scatter(X[kmeans==0,0],X[kmeans==0,1],s=30,c='red',label='Cluster1')       
plt.scatter(X[kmeans==1,0],X[kmeans==1,1],s=30,c='blue',label='Cluster2')       
plt.scatter(X[kmeans==2,0],X[kmeans==2,1],s=30,c='green',label='Cluster3')       
plt.scatter(X[kmeans==3,0],X[kmeans==3,1],s=30,c='orange',label='Cluster4')
plt.scatter(X[kmeans==4,0],X[kmeans==4,1],s=30,c='magenta',label='Cluster5')
plt.legend()
for i,txt in enumerate(n):
    plt.annotate(txt,(z[i],y[i]))

# %%
ret_var['Cluster']=km.labels_
ret_var=ret_var.reset_index()
ret_var
# Out:
#          index  Annual Returns  Volatility  Cluster
# 0         infy       -0.022626    0.418963        0
# 1          ioc       -0.395583    0.499514        2
# 2          itc        0.063885    0.223863        0
# 3           lt       -0.085730    0.314323        0
# 4           mm       -0.268613    0.440357        2
# 5       maruti        0.010174    0.225258        0
# 6     reliance        0.094928    0.439091        0
# 7    sunpharma       -0.146316    0.342426        0
# 8          tcs        0.080307    0.431387        0
# 9        titan        0.472152    0.324361        1
# 10        idbi       -0.295409    0.453787        2
# 11         igl       -0.131495    0.651128        2
# 12     jindals        0.274814    0.492980        4
# 13    jublfood        0.266973    0.501004        4
# 14    mindtree        0.391775    0.341485        1
# 15        mrpl       -0.322303    0.365898        2
# 16        nbcc       -0.514133    0.508672        2
# ...

# %%
# Group by Cluster
g=ret_var.groupby(['Cluster'])

for name,group in g:
    print('\n Stocks of Cluster  :',name)
    print(list(group['index']),'\n')
# Out:
#  Stocks of Cluster  : 0
# ['infy', 'itc', 'lt', 'maruti', 'reliance', 'sunpharma', 'tcs', 'rblbank', 'ncc', 'pvr', 'raymond']
#
#
#  Stocks of Cluster  : 1
# ['titan', 'mindtree', 'luxind', 'sonatsoftw', 'vipind']
#
#
#  Stocks of Cluster  : 2
# ['ioc', 'mm', 'idbi', 'igl', 'mrpl', 'nbcc', 'pnb', 'suzlon']
#
#
#  Stocks of Cluster  : 3
# ['rcom']
#
#
#  Stocks of Cluster  : 4
# ['jindals', 'jublfood', 'mindaind', 'venkeys']
